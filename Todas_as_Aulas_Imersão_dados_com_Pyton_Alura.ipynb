# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoViniciusLT/Repositorio-de-Imersao-de-dados-com-Alura/blob/main/Todas_as_Aulas_Imers%C3%A3o_dados_com_Pyton_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 - Análise de Dados com Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               AU            M
# 3               AU            M
# 4               US            M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas,colunas = df.shape[0] ,df.shape[1]
print('N° de Linhas:',linhas)
print('N° de Colunas:',colunas)
# Out:
# N° de Linhas: 133349
# N° de Colunas: 11

# %%
#Auto explicativo, nos mostra as colunas presentes no arquivo
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
#usamos o gemni para renomear as colunas para português brasileiro
df.rename(columns={
    'work_year': 'ano',
    'experience_level': 'senoridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}, inplace=True)

# %%
df.columns
# Out:
# Index(['ano', 'senoridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["senoridade"].value_counts()
# Out:
# senoridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["contrato"].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
df["empresa"].value_counts()
# Out:
# empresa
# US    119641
# CA      5239
# GB      3719
# AU       522
# NL       404
#        ...
# IR         1
# BS         1
# IQ         1
# CN         1
# MD         1
# Name: count, Length: 95, dtype: int64

# %%
senoridade = {
    'SE': 'Sênior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}

df['senoridade'] = df['senoridade'].replace(senoridade)
df['senoridade'].value_counts()
# Out:
# senoridade
# Sênior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
df['contrato'].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
contrato = {
    'FT' : 'Tempo Integral',
    'CT' : 'Contrato',
    'PT' : 'Meio Periodo',
    'FL' : 'Freelancer'
}
df['contrato'] = df['contrato'].replace(contrato)
df['contrato'].value_counts()
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Meio Periodo         376
# Freelancer            16
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'M' : 'Media',
    'L' : 'Grande',
    'S' : 'Pequena'
}
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# Media      129561
# Grande       3574
# Pequena       214
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['ano', 'senoridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df.head()
# Out:
#       ano senoridade        contrato               cargo  salario moeda  \
# 0  2025.0     Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0     Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0      Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0      Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0     Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia  remoto empresa tamanho_empresa
# 0  214000         US     100      US           Media
# 1  136000         US     100      US           Media
# 2  158800         AU       0      AU           Media
# 3  139200         AU       0      AU           Media
# 4   90000         US       0      US           Media

# %% [markdown]
# # Aula 2 - Limpeza e Preparação de Dados

# %%
df.isnull()
# Out:
#           ano  senoridade  contrato  cargo  salario  moeda    usd  residencia  \
# 0       False       False     False  False    False  False  False       False
# 1       False       False     False  False    False  False  False       False
# 2       False       False     False  False    False  False  False       False
# 3       False       False     False  False    False  False  False       False
# 4       False       False     False  False    False  False  False       False
# ...       ...         ...       ...    ...      ...    ...    ...         ...
# 133344  False       False     False  False    False  False  False       False
# 133345  False       False     False  False    False  False  False       False
# 133346  False       False     False  False    False  False  False       False
# 133347  False       False     False  False    False  False  False       False
# 133348  False       False     False  False    False  False  False       False
#
#         remoto  empresa  tamanho_empresa
# 0        False    False            False
# 1        False    False            False
# 2        False    False            False
# 3        False    False            False
# 4        False    False            False
# ...        ...      ...              ...
# 133344   False    False            False
# 133345   False    False            False
# 133346   False    False            False
# 133347   False    False            False
# 133348   False    False            False
#
# [133349 rows x 11 columns]

# %%
df.head()
# Out:
#       ano senoridade        contrato               cargo  salario moeda  \
# 0  2025.0     Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0     Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0      Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0      Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0     Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia  remoto empresa tamanho_empresa
# 0  214000         US     100      US           Media
# 1  136000         US     100      US           Media
# 2  158800         AU       0      AU           Media
# 3  139200         AU       0      AU           Media
# 4   90000         US       0      US           Media

# %%
df.isnull().sum()
# Out:
# ano                10
# senoridade          0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
#Este método vai nos trazer quais são os valores unicos presentes nesta coluna
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
# Começamos com o DataFrame "df".
# Dentro dos colchetes, colocamos um filtro booleano para decidir quais linhas serão exibidas.
# Aqui, usamos df.isnull() para gerar um DataFrame booleano indicando onde há valores NaN (nulos).
# Em seguida, .any(axis=1) verifica, linha por linha (axis=1 = horizontal),
# se existe pelo menos um valor nulo naquela linha, retornando True ou False.
# Por fim, df[...] retorna apenas as linhas que tiveram True no filtro.
df[df.isnull().any(axis=1)]
# Out:
#         ano senoridade        contrato                      cargo  salario  \
# 5588    NaN     Sênior  Tempo Integral            Product Manager   184500
# 59692   NaN      Pleno  Tempo Integral                   Engineer   110000
# 59710   NaN     Júnior  Tempo Integral             Data Scientist   208800
# 59759   NaN     Sênior  Tempo Integral          Software Engineer   135000
# 59789   NaN     Sênior  Tempo Integral                   Engineer   112000
# 131000  NaN     Sênior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN     Sênior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN     Júnior  Tempo Integral             Data Scientist    40000
# 133281  NaN      Pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN      Pleno  Tempo Integral             Data Scientist   130000
#
#        moeda     usd residencia  remoto empresa tamanho_empresa
# 5588     USD  184500         US       0      US           Media
# 59692    USD  110000         DE       0      DE           Media
# 59710    USD  208800         US       0      US           Media
# 59759    USD  135000         US       0      US           Media
# 59789    USD  112000         US       0      US           Media
# 131000   USD  163800         US       0      US           Media
# 131006   USD  204500         US       0      US           Media
# 133054   USD   40000         JP     100      MY          Grande
# 133281   PLN   46597         PL     100      PL          Grande
# 133317   USD  130000         US      50      US          Grande

# %%
#Importação de biblioteca para operações com numeros
import numpy as np

#Criação de Data Frame para testes
df_salarios = pd.DataFrame({
  'Nome': ["João", "Maria", "Tamara", "Bento", "Plinio"],
  'Salario' : [4000, np.nan, 5000, np.nan, 100000]
})
#df_salarios é nossa base
#salario_media é a nossa coluna que estamos criando
#vamos preencher os salarios da média de salarios
#round é arredondando para 2 casas decimais
'''calcula a média e substitui os nulos e arredonda'''
df_salarios['salario_media'] = df_salarios['Salario'].fillna(df_salarios['Salario'].mean().round(2))

'''Calcula a mediana e substitui os nulos pela mediana'''
df_salarios['salario_mediana'] = df_salarios['Salario'].fillna(df_salarios['Salario'].median())

df_salarios
# Out:
#      Nome   Salario  salario_media  salario_mediana
# 0    João    4000.0        4000.00           4000.0
# 1   Maria       NaN       36333.33           5000.0
# 2  Tamara    5000.0        5000.00           5000.0
# 3   Bento       NaN       36333.33           5000.0
# 4  Plinio  100000.0      100000.00         100000.0

# %%
df_temperaturas = pd.DataFrame({
    'Dia': ['Segunda', 'Terça', 'Quarta','Quinta','Sexta'],
    'Temperatura': [30,np.nan,np.nan,28,27]
})

#vai completar com o valor anterior
df_temperaturas['Preenchido_Ffill'] = df_temperaturas['Temperatura'].ffill()

#vai completar com o valor sucessor
df_temperaturas['Preenchido_Bfill'] = df_temperaturas['Temperatura'].bfill()
df_temperaturas
# Out:
#        Dia  Temperatura  Preenchido_Ffill  Preenchido_Bfill
# 0  Segunda         30.0              30.0              30.0
# 1    Terça          NaN              30.0              28.0
# 2   Quarta          NaN              30.0              28.0
# 3   Quinta         28.0              28.0              28.0
# 4    Sexta         27.0              27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'Nome': ["João", "Maria", "Tamara", "Bento", "Plinio"],
    'Cidades': ['Ponta Grossa', np.nan, 'Eldorado', 'Registro', np.nan]
})

df_cidades['Cidade_Preenchida'] = df_cidades['Cidades'].fillna('Não Informado')
df_cidades
# Out:
#      Nome       Cidades Cidade_Preenchida
# 0    João  Ponta Grossa      Ponta Grossa
# 1   Maria           NaN     Não Informado
# 2  Tamara      Eldorado          Eldorado
# 3   Bento      Registro          Registro
# 4  Plinio           NaN     Não Informado

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senoridade         0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senoridade        contrato               cargo  salario moeda  \
# 0  2025.0     Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0     Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0      Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0      Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0     Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia  remoto empresa tamanho_empresa
# 0  214000         US     100      US           Media
# 1  136000         US     100      US           Media
# 2  158800         AU       0      AU           Media
# 3  139200         AU       0      AU           Media
# 4   90000         US       0      US           Media

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senoridade       133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  int64
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 12.2+ MB

# %%
#Aqui estamos convertendo a varivael do "Ano" de float64 para int64
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  int64
#  1   senoridade       133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  int64
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 12.2+ MB

# %%
df_limpo.head()
# Out:
#     ano senoridade        contrato               cargo  salario moeda     usd  \
# 0  2025     Sênior  Tempo Integral  Solutions Engineer   214000   USD  214000
# 1  2025     Sênior  Tempo Integral  Solutions Engineer   136000   USD  136000
# 2  2025      Pleno  Tempo Integral       Data Engineer   158800   USD  158800
# 3  2025      Pleno  Tempo Integral       Data Engineer   139200   USD  139200
# 4  2025     Júnior  Tempo Integral       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US           Media
# 1         US     100      US           Media
# 2         AU       0      AU           Media
# 3         AU       0      AU           Media
# 4         US       0      US           Media

# %%
df_limpo = df_limpo.assign(salario = df_limpo['salario'].astype('float64'))

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  int64
#  1   senoridade       133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  float64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  int64
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 12.2+ MB

# %%
df_limpo.head()
# Out:
#     ano senoridade        contrato               cargo   salario moeda  \
# 0  2025     Sênior  Tempo Integral  Solutions Engineer  214000.0   USD
# 1  2025     Sênior  Tempo Integral  Solutions Engineer  136000.0   USD
# 2  2025      Pleno  Tempo Integral       Data Engineer  158800.0   USD
# 3  2025      Pleno  Tempo Integral       Data Engineer  139200.0   USD
# 4  2025     Júnior  Tempo Integral       Data Engineer   90000.0   USD
#
#       usd residencia  remoto empresa tamanho_empresa
# 0  214000         US     100      US           Media
# 1  136000         US     100      US           Media
# 2  158800         AU       0      AU           Media
# 3  139200         AU       0      AU           Media
# 4   90000         US       0      US           Media

# %%
df_limpo = df_limpo.assign(usd = df_limpo['usd'].astype('float64'))

# %%
df_limpo.head()
# Out:
#     ano senoridade        contrato               cargo   salario moeda  \
# 0  2025     Sênior  Tempo Integral  Solutions Engineer  214000.0   USD
# 1  2025     Sênior  Tempo Integral  Solutions Engineer  136000.0   USD
# 2  2025      Pleno  Tempo Integral       Data Engineer  158800.0   USD
# 3  2025      Pleno  Tempo Integral       Data Engineer  139200.0   USD
# 4  2025     Júnior  Tempo Integral       Data Engineer   90000.0   USD
#
#         usd residencia  remoto empresa tamanho_empresa
# 0  214000.0         US     100      US           Media
# 1  136000.0         US     100      US           Media
# 2  158800.0         AU       0      AU           Media
# 3  139200.0         AU       0      AU           Media
# 4   90000.0         US       0      US           Media

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  int64
#  1   senoridade       133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  float64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  float64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  int64
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 12.2+ MB

# %% [markdown]
# # Aula 3 - Vizualização de Dados

# %%
df_limpo.head()
# Out:
#     ano senoridade        contrato               cargo   salario moeda  \
# 0  2025     Sênior  Tempo Integral  Solutions Engineer  214000.0   USD
# 1  2025     Sênior  Tempo Integral  Solutions Engineer  136000.0   USD
# 2  2025      Pleno  Tempo Integral       Data Engineer  158800.0   USD
# 3  2025      Pleno  Tempo Integral       Data Engineer  139200.0   USD
# 4  2025     Júnior  Tempo Integral       Data Engineer   90000.0   USD
#
#         usd residencia      remoto empresa tamanho_empresa
# 0  214000.0         US      remoto      US           Media
# 1  136000.0         US      remoto      US           Media
# 2  158800.0         AU  presencial      AU           Media
# 3  139200.0         AU  presencial      AU           Media
# 4   90000.0         US  presencial      US           Media

# %%
#plotando os graficos
df_limpo['senoridade'].value_counts().plot(kind='bar',title='Distribuição de Senoridade')
# Out:
# <Axes: title={'center': 'Distribuição de Senoridade'}, xlabel='senoridade'>

# %%
'''
É uma biblioteca Python para visualização de dados baseada no Matplotlib.
Oferece gráficos mais bonitos e prontos com menos código.
Integra muito bem com Pandas DataFrames.
'''
import seaborn as sns

# %%
sns.barplot(data = df_limpo, x = 'senoridade', y = 'usd')
# Out:
# <Axes: xlabel='senoridade', ylabel='usd'>

# %%
'''
É um conjunto de funções para criar gráficos e visualizações em Python, parecido com a forma como o MATLAB faz.

É a base que muitas bibliotecas (como o Seaborn) usam para exibir gráficos.
'''
import matplotlib.pyplot as plt

# %%
#definindo o tamanho da figura
plt.figure(figsize=(8,5))

#plotando o grafico
sns.barplot(data = df_limpo, x = 'senoridade', y ='usd')

#Colocando titulo para o gráfico
plt.title('Salario médio por nivel de senoridade')

#Definindo o nome para o eixo x
plt.xlabel('Senoridade')

#Definindo nome para o eixo y
plt.ylabel('Salario médio anual (USD)')

#mostrando o grafico
plt.show()

# %%
#Agrupa por 'senoridade', calcula a média de 'usd' e ordena do maior para o menor
df_limpo.groupby('senoridade')['usd'].mean().sort_values(ascending=False)
# Out:
# senoridade
# Executivo    202027.667813
# Sênior       172850.838301
# Pleno        143044.845979
# Júnior        99034.963267
# Name: usd, dtype: float64

# %%
#ordena a senoridade pela media de USD
ordem = df_limpo.groupby('senoridade')['usd'].mean().sort_values(ascending=False).index

# %%
ordem
# Out:
# Index(['Executivo', 'Sênior', 'Pleno', 'Júnior'], dtype='object', name='senoridade')

# %%
plt.figure(figsize=(8,5))
sns.barplot(data = df_limpo, x = 'senoridade', y ='usd',order = ordem) #no final estamos ordenando tudo
plt.title('Salario médio por nivel de senoridade')
plt.xlabel('Senoridade')
plt.ylabel('Salario médio anual (USD)')
plt.show()

# %%
plt.figure(figsize=(8,4))
#criando histograma
#bins = 50 (valores indo 50 a 50)
sns.histplot(df_limpo['usd'], bins=50,kde=True)
plt.title('Distribuição Salarial Anual')
plt.xlabel('Salario (USD)')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(9,5))
#criando histograma
#bins = 50 (valores indo 50 a 50)
sns.histplot(df_limpo['usd'], bins=100,kde=True)
plt.title('Distribuição Salarial Anual')
plt.xlabel('Salario (USD)')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_limpo['usd'])
plt.title('Boxplot Salarial')
plt.xlabel('Salario (USD)')
plt.show()

# %%
ordem_senioridade = ['Júnior','Pleno','Sênior','Executivo']
plt.figure(figsize=(8,5))
sns.boxplot(x = 'senoridade', y='usd',data = df_limpo, order = ordem_senioridade)
plt.title('Distribuição Salarial por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salario (USD)')
plt.show()

# %%
ordem_senioridade = ['Júnior','Pleno','Sênior','Executivo']
plt.figure(figsize=(8,5))
sns.boxplot(x = 'senoridade', y='usd',data = df_limpo, order = ordem_senioridade,palette='Set2',hue='senoridade')
plt.title('Distribuição Salarial por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salario (USD)')
plt.show()

# %%
import plotly.express as px

# %%
#criando graficos interativos de barras
senoridade_media_salarial = df_limpo.groupby('senoridade')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(senoridade_media_salarial, x='senoridade', y='usd', title='Média Salarial por Senioridade',
             labels={'senoridade:': 'Nivel Senoridade','usd':'Media Salarial Anual (USD)'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3df92b59-a793-438a-a870-0d924efb8258" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3df92b59-a793-438a-a870-0d924efb8258")) {                    Plotly.newPlot(                        "3df92b59-a793-438a-a870-0d924efb8258",                        [{"alignmentgroup":"True","hovertemplate":"senoridade=%{x}\u003cbr\u003eMedia Salarial Anual (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Executivo","Sênior","Pleno","Júnior"],"xaxis":"x","y":[202027.6678125,172850.83830079238,143044.8459789432,99034.96326661843],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}] ...

# %%
#fazendo grafico de pizza
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho','quantidade']
fig = px.pie(remoto_contagem,
             names = 'tipo_trabalho',
             values = 'quantidade',
             title = 'Proporção dos tipos de trabalho'

             )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a573ba44-8248-43bd-8020-1ff757e75cab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a573ba44-8248-43bd-8020-1ff757e75cab")) {                    Plotly.newPlot(                        "a573ba44-8248-43bd-8020-1ff757e75cab",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"tipo_trabalho=%{label}\u003cbr\u003equantidade=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["presencial","remoto","hibrido"],"legendgroup":"","name":"","showlegend":true,"values":[105305,27716,318],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"tick ...

# %%
df_limpo['remoto'] = df['remoto'].map({
    0: 'presencial',
    50: 'hibrido',
    100: 'remoto'
})

# %%
#fazendo uma grafico de rosca
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho','quantidade']
fig = px.pie(remoto_contagem,
             names = 'tipo_trabalho',
             values = 'quantidade',
             title = 'Proporção dos tipos de trabalho',
             hole = 0.5
             )
fig.update_traces(textinfo = 'percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="744c4f94-70d4-440f-a647-88366f94b898" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("744c4f94-70d4-440f-a647-88366f94b898")) {                    Plotly.newPlot(                        "744c4f94-70d4-440f-a647-88366f94b898",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"tipo_trabalho=%{label}\u003cbr\u003equantidade=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["presencial","remoto","hibrido"],"legendgroup":"","name":"","showlegend":true,"values":[105305,27716,318],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marke ...

# %%
#Desafio proposto no final da aula.
#Fazer um grafico de salario distribuido por pais do cargo de data science
df_DataScientist = df_limpo[df_limpo['cargo'] == 'Data Scientist']
salario_por_pais_ds = df_DataScientist.groupby('residencia')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(salario_por_pais_ds,
             x = 'residencia',
             y = 'usd',
             title = 'Distribuição de Salário por País para Data Scientists',
             labels = {'residencia': 'País','usd':'Media Salarial Anual(USD)'},
             color = 'residencia',
             barmode = 'stack')
# Formatando os dados e colocando rótulos
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')

# Rotacionando o x em -45
fig.update_layout(xaxis_tickangle=-45)

# Definindo a cor de fundo do gráfico
fig.update_layout(plot_bgcolor='lightgray', paper_bgcolor='white')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="58002671-2a34-4b49-9288-6110bd4619b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58002671-2a34-4b49-9288-6110bd4619b1")) {                    Plotly.newPlot(                        "58002671-2a34-4b49-9288-6110bd4619b1",                        [{"alignmentgroup":"True","hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"US","offsetgroup":"US","orientation":"v","showlegend":true,"textposition":"outside","x":["US"],"xaxis":"x","y":[162802.49460305294],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SG","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SG","offsetgroup":"SG","orientation":"v","showlegend":true,"textposition":"outside","x":["SG"],"xaxis":"x","y":[152522.7142857143],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BG","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BG","offsetgroup":"BG","orientation":"v","showlegend":true,"textposition":"outside","x":["BG"],"xaxis":"x","y":[152500.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CH","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"CH","offsetgroup":"CH","orientation":"v","showlegend":true,"textposition":"outside","x":["CH"],"xaxis":"x","y":[152256.66666666666],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EG","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"EG","offsetgroup":"EG","orientation":"v","showlegend":true,"textposition":"outside","x":["EG"],"xaxis":"x","y":[140690.9090909091],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CA","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"CA","offsetgroup":"CA","orientation":"v","showlegend":true,"textposition":"outside","x":["CA"],"xaxis":"x","y":[140519.98476190475],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MX","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"MX","offsetgroup":"MX","orientation":"v","showlegend":true,"textposition":"outside","x":["MX"],"xaxis":"x","y":[140466.66666666666],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NZ","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"NZ","offsetgroup":"NZ","orientation":"v","showlegend":true,"textposition":"outside","x":["NZ"],"xaxis":"x","y":[122929.75],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JP","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"JP","offsetgroup" ...

# %%
#Desafio proposto no final da aula.
#Fazer um grafico de salario distribuido por pais do cargo de data science
#Aqui estou usando um gráfico de dispersão
df_DataScientist = df_limpo[df_limpo['cargo'] == 'Data Scientist']
salario_por_pais_ds = df_DataScientist.groupby('residencia')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.scatter(salario_por_pais_ds,
             x = 'residencia',
             y = 'usd',
             title = 'Distribuição de Salário por País para Data Scientists',
             labels = {'residencia': 'País','usd':'Media Salarial Anual(USD)'},
             color = 'residencia')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="721417a2-186d-42eb-bb6f-a4864147a830" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("721417a2-186d-42eb-bb6f-a4864147a830")) {                    Plotly.newPlot(                        "721417a2-186d-42eb-bb6f-a4864147a830",                        [{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"US","orientation":"v","showlegend":true,"x":["US"],"xaxis":"x","y":[162802.49460305294],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SG","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"SG","orientation":"v","showlegend":true,"x":["SG"],"xaxis":"x","y":[152522.7142857143],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BG","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"BG","orientation":"v","showlegend":true,"x":["BG"],"xaxis":"x","y":[152500.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CH","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"CH","orientation":"v","showlegend":true,"x":["CH"],"xaxis":"x","y":[152256.66666666666],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EG","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"EG","orientation":"v","showlegend":true,"x":["EG"],"xaxis":"x","y":[140690.9090909091],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CA","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"CA","orientation":"v","showlegend":true,"x":["CA"],"xaxis":"x","y":[140519.98476190475],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MX","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"MX","orientation":"v","showlegend":true,"x":["MX"],"xaxis":"x","y":[140466.66666666666],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NZ","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"NZ","orientation":"v","showlegend":true,"x":["NZ"],"xaxis":"x","y":[122929.75],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JP","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"JP","orientation":"v","showlegend":true,"x":["JP"],"xaxis":"x","y":[121766.66666666667],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AU","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"AU","orientation":"v","showlegend":true,"x":["AU"],"xaxis":"x","y":[112190.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"País=%{x}\u003cbr\u003eMedia Salarial Anual(USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IT","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"IT","orientation":"v","showlegend":true,"x" ...
